# %% [markdown]
# <a href="https://colab.research.google.com/github/ratnesh003/HCLTech-Tasks/blob/main/Silver%20Badge%20Assignments%20/Assignment%204/HCLTech_ML_Assignment_2_Task_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 4

# %% [markdown]
# #### create a toolchain with LLM, Lang chain and NoSQL database such as MongoDB or Redis and upload your information on to the NoSQL database and query it through an LLM
